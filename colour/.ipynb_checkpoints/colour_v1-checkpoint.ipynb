# %% [markdown]
# # HLS

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread("hls.jpg")

# 轉換BGR到HLS
imgHLS = cv2.cvtColor(img, cv2.COLOR_BGR2HLS)

# range of white color in L channel L通道白色範圍
# mask = cv2.inRange(imgHLS[:,:,1], lowerb=250, upperb=255)
mask = cv2.inRange(imgHLS, np.array([0,250,0]), np.array([255,255,255]))

# Apply Mask to original image 將蒙版應用到原始圖像
white_mask = cv2.bitwise_and(img, img, mask=mask)

# %%
plt.imshow(white_mask)

# %%
img = cv2.imread("hls.jpg")

# 轉換BGR到HSV
imgHSV = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# range of white color in L channel L通道白色範圍
# mask = cv2.inRange(imgHSV[:,:,1], lower=250, upper=255)
mask = cv2.inRange(imgHSV, np.array([78,43,46]), np.array([99,255,255]))


# Apply Mask to original image 將蒙版應用到原始圖像
white_mask = cv2.bitwise_and(img,img, mask=mask)

# %%
plt.imshow(white_mask)

# %%
cv2.imshow('white_mask', white_mask)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.imshow(img)
